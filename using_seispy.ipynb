# %% [markdown]
# # Examples of using seispy equations

# %%
import seispy
import matplotlib.pyplot as plt

# %% [markdown]
# ## rand_event_mag
# Generate random magnitudes.

# %%
mags = [seispy.rand_event_mag() for x in range(10000)]
plt.hist(mags)
# Out:
# (array([5.895e+03, 2.492e+03, 9.890e+02, 3.850e+02, 1.410e+02, 5.200e+01,
#         3.000e+01, 8.000e+00, 3.000e+00, 5.000e+00]),
#  array([1.05719964e-04, 4.00279202e-01, 8.00452684e-01, 1.20062617e+00,
#         1.60079965e+00, 2.00097313e+00, 2.40114661e+00, 2.80132009e+00,
#         3.20149357e+00, 3.60166706e+00, 4.00184054e+00]),
#  <BarContainer object of 10 artists>)
